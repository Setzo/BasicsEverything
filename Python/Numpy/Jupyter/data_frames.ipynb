# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import webbrowser

# %%
website='https://en.wikipedia.org/wiki/NFL_win%E2%80%93loss_records'
webbrowser.open(website)
# Out:
# True

# %%
ucl_frame = pd.read_clipboard()
ucl_frame
# Out:
#                                                  Club  Winners  Runners-up  \
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
ucl_frame.columns
# Out:
# Index(['Club', 'Winners', 'Runners-up', 'Years won', 'Years runner-up'], dtype='object')

# %%
ucl_frame.Club
# Out:
# 0                                     Spain Real Madrid
# 1                                           Italy Milan
# 2                                Germany Bayern Munich*
# 3                                     England Liverpool
# 4                                       Spain Barcelona
# 5                                     Netherlands Ajax*
# 6                                  Italy Internazionale
# 7                            England Manchester United*
# 8                                      Portugal Benfica
# 9                             England Nottingham Forest
# 10                                      Italy Juventus*
# 11                                       Portugal Porto
# 12                                      Scotland Celtic
# 13                                Netherlands Feyenoord
# 14                                  England Aston Villa
# 15                                      Germany Hamburg
# 16                             Romania Steaua București
# ...

# %%
ucl_frame['Club']
# Out:
# 0                                     Spain Real Madrid
# 1                                           Italy Milan
# 2                                Germany Bayern Munich*
# 3                                     England Liverpool
# 4                                       Spain Barcelona
# 5                                     Netherlands Ajax*
# 6                                  Italy Internazionale
# 7                            England Manchester United*
# 8                                      Portugal Benfica
# 9                             England Nottingham Forest
# 10                                      Italy Juventus*
# 11                                       Portugal Porto
# 12                                      Scotland Celtic
# 13                                Netherlands Feyenoord
# 14                                  England Aston Villa
# 15                                      Germany Hamburg
# 16                             Romania Steaua București
# ...

# %%
DataFrame(ucl_frame, columns=['Club', 'Winners', 'Runners-up'])
# Out:
#                                                  Club  Winners  Runners-up
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
DataFrame(ucl_frame, columns=['Club', 'Winners', 'Runners-up', 'Non-existing column'])
# Out:
#                                                  Club  Winners  Runners-up  \
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
ucl_frame.head(2)
# Out:
#                 Club  Winners  Runners-up  \
# 0  Spain Real Madrid       12           3
# 1        Italy Milan        7           4
#
#                                            Years won         Years runner-up
# 0  1956, 1957, 1958, 1959, 1960, 1966, 1998, 2000...        1962, 1964, 1981
# 1           1963, 1969, 1989, 1990, 1994, 2003, 2007  1958, 1993, 1995, 2005

# %%
ucl_frame.head()
# Out:
#                      Club  Winners  Runners-up  \
# 0       Spain Real Madrid       12           3
# 1             Italy Milan        7           4
# 2  Germany Bayern Munich*        5           5
# 3       England Liverpool        5           2
# 4         Spain Barcelona        5           3
#
#                                            Years won  \
# 0  1956, 1957, 1958, 1959, 1960, 1966, 1998, 2000...
# 1           1963, 1969, 1989, 1990, 1994, 2003, 2007
# 2                       1974, 1975, 1976, 2001, 2013
# 3                       1977, 1978, 1981, 1984, 2005
# 4                       1992, 2006, 2009, 2011, 2015
#
#                 Years runner-up
# 0              1962, 1964, 1981
# 1        1958, 1993, 1995, 2005
# 2  1982, 1987, 1999, 2010, 2012
# 3                    1985, 2007
# 4              1961, 1986, 1994

# %%
ucl_frame.tail()
# Out:
#                         Club  Winners  Runners-up Years won Years runner-up
# 34                Italy Roma        0           1         —            1984
# 35           Italy Sampdoria        0           1         —            1992
# 36  Germany Bayer Leverkusen        0           1         —            2002
# 37             France Monaco        0           1         —            2004
# 38           England Arsenal        0           1         —            2006

# %%
ucl_frame.tail(2)
# Out:
#                Club  Winners  Runners-up Years won Years runner-up
# 37    France Monaco        0           1         —            2004
# 38  England Arsenal        0           1         —            2006

# %%
ucl_frame.iloc[3] # Fourth row
# Out:
# Club                          England Liverpool
# Winners                                       5
# Runners-up                                    2
# Years won          1977, 1978, 1981, 1984, 2005
# Years runner-up                      1985, 2007
# Name: 3, dtype: object

# %%
ucl_frame['New column'] = 'Some value'
ucl_frame
# Out:
#                                                  Club  Winners  Runners-up  \
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
ucl_frame['New column'] = np.arange(len(ucl_frame)) * 2
ucl_frame
# Out:
#                                                  Club  Winners  Runners-up  \
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
new_column_values = Series(["Real", "Man Utd"], index=[38, 0])
new_column_values
# Out:
# 38       Real
# 0     Man Utd
# dtype: object

# %%
ucl_frame['New column'] = new_column_values
ucl_frame
# Out:
#                                                  Club  Winners  Runners-up  \
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
del ucl_frame['New column']
ucl_frame
# Out:
#                                                  Club  Winners  Runners-up  \
# 0                                   Spain Real Madrid       12           3
# 1                                         Italy Milan        7           4
# 2                              Germany Bayern Munich*        5           5
# 3                                   England Liverpool        5           2
# 4                                     Spain Barcelona        5           3
# 5                                   Netherlands Ajax*        4           2
# 6                                Italy Internazionale        3           2
# 7                          England Manchester United*        3           2
# 8                                    Portugal Benfica        2           5
# 9                           England Nottingham Forest        2           0
# 10                                    Italy Juventus*        2           7
# ...

# %%
data = {'Letter': ['S', 'A', 'E'], 'Fans': [1, 2, 3]}
data
# Out:
# {'Fans': [1, 2, 3], 'Letter': ['S', 'A', 'E']}

# %%
data_frame = DataFrame(data)
data_frame
# Out:
#    Fans Letter
# 0     1      S
# 1     2      A
# 2     3      E
