# %%
import pandas as pd
from pandas import Series, DataFrame
from pandas import read_html

# %%
url = 'https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
dframe_list = read_html(url)

# %%
dframe = dframe_list[2]
dframe
# Out:
#                            0        1           2  \
# 0                 v t e Club  Winners  Runners-up
# 1                Real Madrid       12           3
# 2                      Milan        7           4
# 3              Bayern Munich        5           5
# 4                  Barcelona        5           3
# 5                  Liverpool        5           2
# 6                       Ajax        4           2
# 7             Internazionale        3           2
# 8          Manchester United        3           2
# 9                   Juventus        2           7
# 10                   Benfica        2           5
# 11         Nottingham Forest        2           0
# 12                     Porto        2           0
# 13                    Celtic        1           1
# 14                   Hamburg        1           1
# 15          Steaua București        1           1
# 16                 Marseille        1           1
# 17         Borussia Dortmund        1           1
# ...

# %%
dframe.columns.values
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)
